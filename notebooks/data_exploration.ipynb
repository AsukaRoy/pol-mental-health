# %%
import pandas as pd
import gzip
import json

# %%
print(f"🔍 Reading gzip NDJSON file: {'/m/cs/scratch/sinitaivas/bluesky_firehose/firehose_stream/2024-12-17/2024-12-17T21.ndjson.gz'}")
records = []
with gzip.open('/m/cs/scratch/sinitaivas/bluesky_firehose/firehose_stream/2024-12-17/2024-12-17T21.ndjson.gz', "rt", encoding="utf-8") as f:
    for i, line in enumerate(f):
        try:
            records.append(json.loads(line))
        except json.JSONDecodeError:
            continue  # skip any malformed line
        if i >= 50000:  # optional: read only first N lines for faster testing
            break

if not records:
    raise ValueError("No valid JSON records found in the NDJSON file!")

df = pd.DataFrame(records)
# Out:
# 🔍 Reading gzip NDJSON file: /m/cs/scratch/sinitaivas/bluesky_firehose/firehose_stream/2024-12-17/2024-12-17T21.ndjson.gz

# %%
df.columns.to_list()
# Out:
# ['seq',
#  'collected_at',
#  'commit_time',
#  'action',
#  'type',
#  'uri',
#  'author',
#  'cid',
#  'createdAt',
#  'subject',
#  '$type',
#  'text',
#  'embed',
#  'facets',
#  'langs',
#  'reply',
#  'via',
#  'avatar',
#  'description',
#  'displayName',
#  'labels',
#  'banner',
#  'pinnedPost',
#  'list',
#  'tags',
#  'name',
#  'purpose',
#  'descriptionFacets',
#  'feeds',
#  'updatedAt',
#  'post',
#  'allow',
#  'hiddenReplies',
#  'detachedEmbeddingUris',
#  'embeddingRules',
#  'allowIncoming',
#  'bridgyOriginalUrl',
#  'bridgyOriginalText',
#  'did']

# %%
df
# Out:
#               seq                 collected_at               commit_time  \
# 0      1901703577  2024-12-17T21:53:39.298943Z  2024-12-17T20:48:55.230Z
# 1      1901703578  2024-12-17T21:53:39.300716Z  2024-12-17T20:48:55.230Z
# 2      1901703579  2024-12-17T21:53:39.483770Z  2024-12-17T20:48:55.235Z
# 3      1901703580  2024-12-17T21:53:39.484729Z  2024-12-17T20:48:55.235Z
# 5      1901703582  2024-12-17T21:53:39.486147Z  2024-12-17T20:48:55.237Z
# ...           ...                          ...                       ...
# 49996  1901752052  2024-12-17T21:54:08.741604Z  2024-12-17T20:49:58.764Z
# 49997  1901752053  2024-12-17T21:54:08.742170Z  2024-12-17T20:49:58.764Z
# 49998  1901752054  2024-12-17T21:54:08.742662Z  2024-12-17T20:49:58.764Z
# 49999  1901752055  2024-12-17T21:54:08.743149Z  2024-12-17T20:49:58.764Z
# 50000  1901752056  2024-12-17T21:54:08.743762Z  2024-12-17T20:49:58.764Z
#
#        action                   type  \
# 0      create  app.bsky.graph.follow
# 1      create     app.bsky.feed.post
# 2      create     app.bsky.feed.like
# 3      create     app.bsky.feed.post
# 5      create     app.bsky.feed.like
# ...       ...                    ...
# 49996  create     app.bsky.feed.like
# 49997  create     app.bsky.feed.like
# 49998  create     app.bsky.feed.like
# 49999  create   app.bsky.feed.repost
# 50000  create     app.bsky.feed.like
#
#                                                      uri  \
# 0      at://did:plc:4buvsj3cnv2q7wwvqazste2u/app.bsky...
# 1      at://did:plc:32b7gn3etnrw42ithvyl5yrh/app.bsky...
# 2      at://did:plc:tuxo5up6pstoxa3k33icljph/app.bsky...
# 3      at://did:plc:4lmrw65t5zpy7iiqtot4lgsg/app.bsky...
# 49997  {'cid': 'bafyreid3qquieij5mg3q3dx2guc7px55gmqx...  ...  NaN   NaN
# 49998  {'cid': 'bafyreiarqqvvqndkmw5jfvgq5dofgjopfhra...  ...  NaN   NaN
# 49999  {'cid': 'bafyreiewnytjjzcamyiowwtzwiznhdp54l5s...  ...  NaN   NaN
# 50000  {'cid': 'bafyreicdvikuwy33b5gtainu4cfjyymsjgnx...  ...  NaN   NaN
#
#       hiddenReplies detachedEmbeddingUris embeddingRules allowIncoming  \
# 0               NaN                   NaN            NaN           NaN
# 1               NaN                   NaN            NaN           NaN
# 2               NaN                   NaN            NaN           NaN
# 3               NaN                   NaN            NaN           NaN
# 5               NaN                   NaN            NaN           NaN
# ...             ...                   ...            ...           ...
# 49996           NaN                   NaN            NaN           NaN
# 49997           NaN                   NaN            NaN           NaN
# 49998           NaN                   NaN            NaN           NaN
# 49999           NaN                   NaN            NaN           NaN
# 50000           NaN                   NaN            NaN           NaN
#
#       bridgyOriginalUrl bridgyOriginalText  did action_category
# 0                   NaN                NaN  NaN         follows
# 1                   NaN                NaN  NaN           posts
# 2                   NaN                NaN  NaN           likes
# 3                   NaN                NaN  NaN           posts
# 5                   NaN                NaN  NaN           likes
# ...                 ...                ...  ...             ...
# 49996               NaN                NaN  NaN           likes
# 49997               NaN                NaN  NaN           likes
# 49998               NaN                NaN  NaN           likes
# 49999               NaN                NaN  NaN         reposts
# 50000               NaN                NaN  NaN           likes
#
# [48822 rows x 40 columns]

# %%
#df.to_csv("sample.csv", index = None)

# %%
# Define mapping of action types
action_map = {
    "app.bsky.feed.post": "posts",
    "app.bsky.feed.repost": "reposts",
    "app.bsky.graph.follow": "follows",
    "app.bsky.feed.like": "likes"
}

# Filter only known types
df = df[df["type"].isin(action_map.keys())]

# Map each action to a category (post, repost, follow, like)
df["action_category"] = df["type"].map(action_map)
summary = (
df.groupby(["author", "action_category"])
.size()
.unstack(fill_value=0)
.reset_index()
)
summary
# Out:
# action_category                            author  follows  likes  posts  \
# 0                did:plc:223f5neubhxazapvd5mmwioi        0      2      0
# 1                did:plc:226w3kve33nnfblfixvwwgto        2      0      0
# 2                did:plc:227mqd3o26tynduwdgdbxqu6        1      0      0
# 3                did:plc:22coqmaear2fwlrollu5hoax        1      2      1
# 4                did:plc:22gvahvnw2gk3eru5ildy4dj        0      1      0
# ...                                           ...      ...    ...    ...
# 19926            did:plc:zzozknebkvtval5uurylqv2n        0      2      2
# 19927            did:plc:zzphfrojjsktrshfiwpj3daa        0      1      0
# 19928            did:plc:zzsvmwqu6ec4dq23m2nrgj2u        0      0      0
# 19929            did:plc:zzugejr3gecohv7day6xwxbi        0      1      0
# 19930                       did:web:hugeblank.dev        0      0      3
#
# action_category  reposts
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 19926                  0
# 19927                  0
# 19928                  1
# 19929                  0
# 19930                  0
#
# [19931 rows x 5 columns]

# %%
input_df = pd.read_parquet('/scratch/cs/ecanet/polwell-mental-health/polwell_mh/data/processed/LIWC/postsLiwcDF_2025-01-01.parquet')

# %%
input_df.sample(1000).to_csv('/m/cs/scratch/ecanet/polwell-mental-health/polwell_mh/data/testdata/postsLiwcDF.csv', index = None)
